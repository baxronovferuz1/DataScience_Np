# %% [markdown]
# <a href="https://colab.research.google.com/github/baxronovferuz1/DataScience_Np/blob/main/data_processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Hierarchical indexing

# %%
import numpy as np
import pandas as pd

# %%
data=pd.Series(np.random.randint(7), index=['a','a','b','b','c','c','d'])
data.index
# Out:
# Index(['a', 'a', 'b', 'b', 'c', 'c', 'd'], dtype='object')

# %%
ind_data=pd.Series(np.random.randn(7), index=[['a','a','b','b','c','c','d'],[1,3,1,3,1,3,1]])
ind_data.index
# Out:
# MultiIndex([('a', 1),
#             ('a', 3),
#             ('b', 1),
#             ('b', 3),
#             ('c', 1),
#             ('c', 3),
#             ('d', 1)],
#            )

# %%
ind_data
# Out:
# a  1    3
#    3    3
# b  1    3
#    3    3
# c  1    3
#    3    3
# d  1    3
# dtype: int64

# %%
ind_data["a"]
# Out:
# 1    3
# 3    3
# dtype: int64

# %%
data
# Out:
# a    5
# a    5
# b    5
# b    5
# c    5
# c    5
# d    5
# dtype: int64

# %%
ind_data
# Out:
# a  1   -1.026819
#    3    0.033638
# b  1    0.383357
#    3    2.072679
# c  1   -0.615863
#    3   -1.105408
# d  1    2.008173
# dtype: float64

# %%
ind_data.loc[:,1]
# Out:
# a   -1.026819
# b    0.383357
# c   -0.615863
# d    2.008173
# dtype: float64

# %%
ind_data[["a","c"]]
# Out:
# a  1   -1.026819
#    3    0.033638
# c  1   -0.615863
#    3   -1.105408
# dtype: float64

# %%
ind_data.unstack()
# Out:
#           1         3
# a -1.026819  0.033638
# b  0.383357  2.072679
# c -0.615863 -1.105408
# d  2.008173       NaN

# %%
ind_data.unstack().stack()
# Out:
# a  1   -1.026819
#    3    0.033638
# b  1    0.383357
#    3    2.072679
# c  1   -0.615863
#    3   -1.105408
# d  1    2.008173
# dtype: float64

# %%
from google.colab import files

# %%
uploaded=files.upload()
# Out:
#      <input type="file" id="files-4d0d3ca4-5591-48cc-a95b-ca13864dbee1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4d0d3ca4-5591-48cc-a95b-ca13864dbee1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
a_w=pd.read_csv("/content/cities_air_quality_water_pollution.18-10-2021.csv")

# %%
a_w
# Out:
#                   City                 "Region"                    "Country"  \
# 0        New York City               "New York"   "United States of America"
# 1     Washington, D.C.   "District of Columbia"   "United States of America"
# 2        San Francisco             "California"   "United States of America"
# 3               Berlin                       ""                    "Germany"
# 4          Los Angeles             "California"   "United States of America"
# ...                ...                      ...                          ...
# 3958             Yanbu        "Medina Province"               "Saudi Arabia"
# 3959           Cordoba              "Andalusia"                      "Spain"
# 3960               Vic              "Catalonia"                      "Spain"
# 3961           Segovia       "Castile and Leon"                      "Spain"
# 3962       Zamora city       "Castile and Leon"                      "Spain"
#
#        "AirQuality"   "WaterPollution"
# ...

# %% [markdown]
# Air quality varies from 0 (bad quality) to 100 (top good quality)
#
# Water pollution varies from 0 (no pollution) to 100 (extreme pollution)

# %%
a_w.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3963 entries, 0 to 3962
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   City               3963 non-null   object
#  1    "Region"          3963 non-null   object
#  2    "Country"         3963 non-null   object
#  3    "AirQuality"      3963 non-null   float64
#  4    "WaterPollution"  3963 non-null   float64
# dtypes: float64(2), object(3)
# memory usage: 154.9+ KB

# %%
columns=["City","Region","Country","AirQuality","WaterPollution"]
a_w.columns=columns

# %%
a_w
# Out:
#                   City                   Region                      Country  \
# 0        New York City               "New York"   "United States of America"
# 1     Washington, D.C.   "District of Columbia"   "United States of America"
# 2        San Francisco             "California"   "United States of America"
# 3               Berlin                       ""                    "Germany"
# 4          Los Angeles             "California"   "United States of America"
# ...                ...                      ...                          ...
# 3958             Yanbu        "Medina Province"               "Saudi Arabia"
# 3959           Cordoba              "Andalusia"                      "Spain"
# 3960               Vic              "Catalonia"                      "Spain"
# 3961           Segovia       "Castile and Leon"                      "Spain"
# 3962       Zamora city       "Castile and Leon"                      "Spain"
#
#       AirQuality  WaterPollution
# ...

# %%
a_w["Region"]=a_w['Region'].map(lambda x: x.replace('"',''))
a_w
# Out:
#                   City                 Region                      Country  \
# 0        New York City               New York   "United States of America"
# 1     Washington, D.C.   District of Columbia   "United States of America"
# 2        San Francisco             California   "United States of America"
# 3               Berlin                                           "Germany"
# 4          Los Angeles             California   "United States of America"
# ...                ...                    ...                          ...
# 3958             Yanbu        Medina Province               "Saudi Arabia"
# 3959           Cordoba              Andalusia                      "Spain"
# 3960               Vic              Catalonia                      "Spain"
# 3961           Segovia       Castile and Leon                      "Spain"
# 3962       Zamora city       Castile and Leon                      "Spain"
#
#       AirQuality  WaterPollution
# 0      46.816038       49.504950
# ...

# %%
a_w["Country"]=a_w["Country"].map(lambda x: x.replace('"',''))
a_w
# Out:
#                   City                 Region                    Country  \
# 0        New York City               New York   United States of America
# 1     Washington, D.C.   District of Columbia   United States of America
# 2        San Francisco             California   United States of America
# 3               Berlin                                           Germany
# 4          Los Angeles             California   United States of America
# ...                ...                    ...                        ...
# 3958             Yanbu        Medina Province               Saudi Arabia
# 3959           Cordoba              Andalusia                      Spain
# 3960               Vic              Catalonia                      Spain
# 3961           Segovia       Castile and Leon                      Spain
# 3962       Zamora city       Castile and Leon                      Spain
#
#       AirQuality  WaterPollution
# 0      46.816038       49.504950
# ...

# %%
a_w["Region"][2]
# Out:
# ' California'

# %%
a_w["Region"]=a_w["Region"].map(lambda x:x.strip())
a_w
# Out:
#                   City                Region                    Country  \
# 0        New York City              New York   United States of America
# 1     Washington, D.C.  District of Columbia   United States of America
# 2        San Francisco            California   United States of America
# 3               Berlin                                          Germany
# 4          Los Angeles            California   United States of America
# ...                ...                   ...                        ...
# 3958             Yanbu       Medina Province               Saudi Arabia
# 3959           Cordoba             Andalusia                      Spain
# 3960               Vic             Catalonia                      Spain
# 3961           Segovia      Castile and Leon                      Spain
# 3962       Zamora city      Castile and Leon                      Spain
#
#       AirQuality  WaterPollution
# 0      46.816038       49.504950
# 1      66.129032       49.107143
# ...

# %%
a_w["Region"][4]
# Out:
# 'California'

# %%
a_w[a_w["Region"]=="California"]
# Out:
#                   City      Region                    Country  AirQuality  \
# 2        San Francisco  California   United States of America   60.514019
# 4          Los Angeles  California   United States of America   36.621622
# 447   Huntington Beach  California   United States of America   85.714286
# 678          San Diego  California   United States of America   74.382716
# 679           San Jose  California   United States of America   62.209302
# ...                ...         ...                        ...         ...
# 3318            Marina  California   United States of America  100.000000
# 3347       Foster City  California   United States of America  100.000000
# 3665          Lakeport  California   United States of America  100.000000
# 3666           Jackson  California   United States of America  100.000000
# 3769             Yreka  California   United States of America  100.000000
#
#       WaterPollution
# 2          43.000000
# 4          61.299435
# ...

# %%
# df=pd.pivot_table(a_w, index=["Country","City"])
# df

# %%
a_w["Country"][2]
# Out:
# ' United States of America'

# %%
# a_w["Country"]=a_w["Country"].map(lambda x:x.strip())
# a_w

# %%
a_w["Country"][2]
# Out:
# <function str.strip(chars=None, /)>

# %%
a_w["Country"].head()
# Out:
# 0    <built-in method strip of str object at 0x7b6c...
# 1    <built-in method strip of str object at 0x7b6c...
# 2    <built-in method strip of str object at 0x7b6c...
# 3    <built-in method strip of str object at 0x7b6c...
# 4    <built-in method strip of str object at 0x7b6c...
# Name: Country, dtype: object

# %%
print(a_w["Country"].head())
# Out:
# 0    <built-in method strip of str object at 0x7b6c...
# 1    <built-in method strip of str object at 0x7b6c...
# 2    <built-in method strip of str object at 0x7b6c...
# 3    <built-in method strip of str object at 0x7b6c...
# 4    <built-in method strip of str object at 0x7b6c...
# Name: Country, dtype: object

# %%
print(a_w["Country"].dtype)
# Out:
# object

# %%
a_w["Country"] = a_w["Country"].astype(str)

# %%
print(a_w["Country"].dtype)
# Out:
# object

# %%
print(a_w["Country"].head())
# Out:
# 0    <built-in method strip of str object at 0x7b6c...
# 1    <built-in method strip of str object at 0x7b6c...
# 2    <built-in method strip of str object at 0x7b6c...
# 3    <built-in method strip of str object at 0x7b6c...
# 4    <built-in method strip of str object at 0x7b6c...
# Name: Country, dtype: object

# %%
a_w.to_csv("updateddataset_csv", index=False)

# %%
# df=pd.pivot_table(a_w, index=["Country","City"])
# df

# %%
df=a_w.copy()
df
# Out:
#                   City                Region  \
# 0        New York City              New York
# 1     Washington, D.C.  District of Columbia
# 2        San Francisco            California
# 3               Berlin
# 4          Los Angeles            California
# ...                ...                   ...
# 3958             Yanbu       Medina Province
# 3959           Cordoba             Andalusia
# 3960               Vic             Catalonia
# 3961           Segovia      Castile and Leon
# 3962       Zamora city      Castile and Leon
#
#                                                 Country  AirQuality  \
# 0     <built-in method strip of str object at 0x7b6c...   46.816038
# 1     <built-in method strip of str object at 0x7b6c...   66.129032
# 2     <built-in method strip of str object at 0x7b6c...   60.514019
# 3     <built-in method strip of str object at 0x7b6c...   62.364130
# 4     <built-in method strip of str object at 0x7b6c...   36.621622
# ...

# %%
df["Country"] = df["Country"].str.strip()

# %%
df
# Out:
#                   City                Region  \
# 0        New York City              New York
# 1     Washington, D.C.  District of Columbia
# 2        San Francisco            California
# 3               Berlin
# 4          Los Angeles            California
# ...                ...                   ...
# 3958             Yanbu       Medina Province
# 3959           Cordoba             Andalusia
# 3960               Vic             Catalonia
# 3961           Segovia      Castile and Leon
# 3962       Zamora city      Castile and Leon
#
#                                                 Country  AirQuality  \
# 0     <built-in method strip of str object at 0x7b6c...   46.816038
# 1     <built-in method strip of str object at 0x7b6c...   66.129032
# 2     <built-in method strip of str object at 0x7b6c...   60.514019
# 3     <built-in method strip of str object at 0x7b6c...   62.364130
# 4     <built-in method strip of str object at 0x7b6c...   36.621622
# ...

# %%
a_w["AirPollution"]=100-a_w["AirQuality"]
a_w
# Out:
#                   City                Region  \
# 0        New York City              New York
# 1     Washington, D.C.  District of Columbia
# 2        San Francisco            California
# 3               Berlin
# 4          Los Angeles            California
# ...                ...                   ...
# 3958             Yanbu       Medina Province
# 3959           Cordoba             Andalusia
# 3960               Vic             Catalonia
# 3961           Segovia      Castile and Leon
# 3962       Zamora city      Castile and Leon
#
#                                                 Country  AirQuality  \
# 0     <built-in method strip of str object at 0x7b6c...   46.816038
# 1     <built-in method strip of str object at 0x7b6c...   66.129032
# 2     <built-in method strip of str object at 0x7b6c...   60.514019
# 3     <built-in method strip of str object at 0x7b6c...   62.364130
# 4     <built-in method strip of str object at 0x7b6c...   36.621622
# ...

# %%
a_w["WaterQuality"]=100-a_w["WaterPollution"]
a_w
# Out:
#                   City                Region  \
# 0        New York City              New York
# 1     Washington, D.C.  District of Columbia
# 2        San Francisco            California
# 3               Berlin
# 4          Los Angeles            California
# ...                ...                   ...
# 3958             Yanbu       Medina Province
# 3959           Cordoba             Andalusia
# 3960               Vic             Catalonia
# 3961           Segovia      Castile and Leon
# 3962       Zamora city      Castile and Leon
#
#                                                 Country  AirQuality  \
# 0     <built-in method strip of str object at 0x7b6c...   46.816038
# 1     <built-in method strip of str object at 0x7b6c...   66.129032
# 2     <built-in method strip of str object at 0x7b6c...   60.514019
# 3     <built-in method strip of str object at 0x7b6c...   62.364130
# 4     <built-in method strip of str object at 0x7b6c...   36.621622
# ...

# %%
idf=pd.DataFrame(a_w.values, index=a_w.index, columns=[["AIR","AIR","WATER","WATER","CITY","REGION","COUNTRY"],["AirPollution","AirQuality","WaterPollution","WaterQuality","City","Region","Country"]])
idf
# Out:
#                    AIR                        \
#           AirPollution            AirQuality
# 0        New York City              New York
# 1     Washington, D.C.  District of Columbia
# 2        San Francisco            California
# 3               Berlin
# 4          Los Angeles            California
# ...                ...                   ...
# 3958             Yanbu       Medina Province
# 3959           Cordoba             Andalusia
# 3960               Vic             Catalonia
# 3961           Segovia      Castile and Leon
# 3962       Zamora city      Castile and Leon
#
#                                                   WATER               \
#                                          WaterPollution WaterQuality
# 0     <built-in method strip of str object at 0x7b6c...    46.816038
# 1     <built-in method strip of str object at 0x7b6c...    66.129032
# 2     <built-in method strip of str object at 0x7b6c...    60.514019
# ...
